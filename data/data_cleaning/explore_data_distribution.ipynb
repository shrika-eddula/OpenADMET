# %%
from chemprop import data, featurizers, models, nn

# %%
# Imports
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
combined = pd.read_csv("/home/shrika/OpenADMET/Data/splits/Combined_Log10_Transformed_Canon_SMILES_Duplicates_Merged.csv", index_col=False)

# %%
combined.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  \
# 0             0           0
# 1             1           1
# 2             2           2
# 3             3           3
# 4             4           4
#
#                                               SMILES Molecule Name  LogD  \
# 0  CN1CCC[C@H]1COc1ccc(-c2nc3cc(-c4ccc5[nH]c(-c6c...     E-0001321   NaN
# 1                  COc1ccc2c(c1)c1cc3cnccc3c(C)c1n2C     E-0001780   NaN
# 2     Cc1c2ccncc2cc2c3cc(OCCCN4CCN(C)CC4)ccc3n(C)c12     E-0001827   NaN
# 3  CN(C)CCCOc1ccc(-c2nc3cc(NC(=O)c4ccc5[nH]c(-c6c...     E-0002019   NaN
# 4  CN(C)CCCOc1ccc2nc(-c3ccc(-c4nc5ccc(OCCCN(C)C)c...     E-0002036   NaN
#
#    LogS  Log_HLM_CLint  Log_MLM_CLint  Log_Caco_Papp_AB  Log_Caco_ER  \
# 0   NaN       1.758912       2.263162               NaN          NaN
# 1   NaN       2.207904       3.131009               NaN          NaN
# 2   NaN            NaN       2.288920               NaN          NaN
# 3   NaN       1.021189            NaN               NaN          NaN
# ...

# %%
combined.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'SMILES', 'Molecule Name', 'LogD', 'LogS',
#        'Log_HLM_CLint', 'Log_MLM_CLint', 'Log_Caco_Papp_AB', 'Log_Caco_ER',
#        'Log_Mouse_PPB', 'Log_Mouse_BPB', 'Log_Mouse_MPB'],
#       dtype='object')

# %%
# Remove the unwanted Unnamed columns
clean_combined = combined.drop(columns=['Unnamed: 0.1', 'Unnamed: 0'])
clean_combined.head()
# Out:
#                                               SMILES Molecule Name  LogD  \
# 0  CN1CCC[C@H]1COc1ccc(-c2nc3cc(-c4ccc5[nH]c(-c6c...     E-0001321   NaN
# 1                  COc1ccc2c(c1)c1cc3cnccc3c(C)c1n2C     E-0001780   NaN
# 2     Cc1c2ccncc2cc2c3cc(OCCCN4CCN(C)CC4)ccc3n(C)c12     E-0001827   NaN
# 3  CN(C)CCCOc1ccc(-c2nc3cc(NC(=O)c4ccc5[nH]c(-c6c...     E-0002019   NaN
# 4  CN(C)CCCOc1ccc2nc(-c3ccc(-c4nc5ccc(OCCCN(C)C)c...     E-0002036   NaN
#
#    LogS  Log_HLM_CLint  Log_MLM_CLint  Log_Caco_Papp_AB  Log_Caco_ER  \
# 0   NaN       1.758912       2.263162               NaN          NaN
# 1   NaN       2.207904       3.131009               NaN          NaN
# 2   NaN            NaN       2.288920               NaN          NaN
# 3   NaN       1.021189            NaN               NaN          NaN
# 4   NaN            NaN       2.212188               NaN          NaN
#
#    Log_Mouse_PPB  Log_Mouse_BPB  Log_Mouse_MPB
# 0            NaN            NaN            NaN
# ...

# %%
# Save the cleaned DataFrame to CSV
clean_combined.to_csv("/home/shrika/OpenADMET/Data/splits/FINAL_DATA.csv", index=False)

print("✅ Cleaned data saved to FINAL_DATA.csv with shape:", clean_combined.shape)
